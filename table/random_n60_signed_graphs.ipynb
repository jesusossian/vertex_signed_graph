# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdfkit as pdf

# %%
prob_ = "signed_graphs"
n_ = 60

# %%
method_ = "lp"
file=f"../result/{method_}_n{n_}_{prob_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_lp = pd.DataFrame()
table_lp = pd.concat([table_lp, df], ignore_index=True)
table_lp.columns = ['instance','bs','time']

method_ = "mip"
file=f"../result/{method_}_n{n_}_{prob_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_mip = pd.DataFrame()
table_mip = pd.concat([table_mip, df], ignore_index=True)
table_mip.columns = ['instance','bb','bs','gap','time','nodes','opt']

table_mip['lp'] = table_lp['bs']
table_mip['gap_lp'] = (table_lp['bs'] - table_mip['bs'])/table_mip['bs']

table_mip_ineq6 = table_mip
table_mip_ineq6
# Out:
#                               instance    bb    bs  gap    time   nodes  opt  \
# 0    random_n60_k2_pos30_neg5_err5_1.g  47.0  47.0  0.0  156.99    14.0    1
# 1    random_n60_k2_pos30_neg5_err5_2.g  54.0  54.0  0.0    9.91     1.0    1
# 2    random_n60_k2_pos30_neg5_err5_3.g  53.0  53.0  0.0   12.13     1.0    1
# 3    random_n60_k2_pos30_neg5_err5_4.g  49.0  49.0  0.0   31.40     1.0    1
# 4    random_n60_k2_pos30_neg5_err5_5.g  49.0  49.0  0.0   84.25     1.0    1
# 5   random_n60_k2_pos30_neg5_err10_1.g  42.0  42.0  0.0  116.11   181.0    1
# 6   random_n60_k2_pos30_neg5_err10_2.g  48.0  48.0  0.0   66.03    17.0    1
# 7   random_n60_k2_pos30_neg5_err10_3.g  43.0  43.0  0.0  127.07   170.0    1
# 8   random_n60_k2_pos30_neg5_err10_4.g  39.0  39.0  0.0  161.93   542.0    1
# 9   random_n60_k2_pos30_neg5_err10_5.g  42.0  42.0  0.0  163.58   294.0    1
# 10  random_n60_k2_pos30_neg5_err20_1.g  36.0  36.0  0.0  148.24  2554.0    1
# ...

# %%
method_ = "lp"
file=f"../result/{method_}_n{n_}_{prob_}_ineq9.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_lp = pd.DataFrame()
table_lp = pd.concat([table_lp, df], ignore_index=True)
table_lp.columns = ['instance','bs','time']

method_ = "mip"
file=f"../result/{method_}_n{n_}_{prob_}_ineq9.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_mip = pd.DataFrame()
table_mip = pd.concat([table_mip, df], ignore_index=True)
table_mip.columns = ['instance','bb','bs','gap','time','nodes','opt']

table_mip['lp'] = table_lp['bs']
table_mip['gap_lp'] = (table_lp['bs'] - table_mip['bs'])/table_mip['bs']

table_mip_ineq9 = table_mip
table_mip_ineq9
# Out:
#                               instance    bb    bs  gap    time    nodes  opt  \
# 0    random_n60_k2_pos30_neg5_err5_1.g  47.0  47.0  0.0   37.96     19.0    1
# 1    random_n60_k2_pos30_neg5_err5_2.g  54.0  54.0  0.0    2.33      1.0    1
# 2    random_n60_k2_pos30_neg5_err5_3.g  53.0  53.0  0.0    5.09      1.0    1
# 3    random_n60_k2_pos30_neg5_err5_4.g  49.0  49.0  0.0    6.31      1.0    1
# 4    random_n60_k2_pos30_neg5_err5_5.g  49.0  49.0  0.0   35.18      1.0    1
# 5   random_n60_k2_pos30_neg5_err10_1.g  42.0  42.0  0.0   54.24    352.0    1
# 6   random_n60_k2_pos30_neg5_err10_2.g  48.0  48.0  0.0   34.28     17.0    1
# 7   random_n60_k2_pos30_neg5_err10_3.g  43.0  43.0  0.0   73.16    256.0    1
# 8   random_n60_k2_pos30_neg5_err10_4.g  39.0  39.0  0.0   75.08    814.0    1
# 9   random_n60_k2_pos30_neg5_err10_5.g  42.0  42.0  0.0   61.83    416.0    1
# 10  random_n60_k2_pos30_neg5_err20_1.g  36.0  36.0  0.0  207.52   1633.0    1
# ...

# %%
method_ = "lp"
file=f"../result/{method_}_n{n_}_{prob_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_lp0 = pd.DataFrame()
table_lp0 = pd.concat([table_lp0, df], ignore_index=True)
table_lp0.columns = ['instance','bs0','time0']


method_ = "lp"
file=f"../result/{method_}_n{n_}_{prob_}_ineq9.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_lp1 = pd.DataFrame()
table_lp1 = pd.concat([table_lp1, df], ignore_index=True)
table_lp1.columns = ['instance','bs1','time1']


table_lp0['bs1'] = table_lp1['bs1']
table_lp0['time1'] = table_lp1['time1']


table_lp0
# Out:
#                               instance    bs0  time0    bs1  time1
# 0    random_n60_k2_pos30_neg5_err5_1.g  58.88   0.78  54.08   0.64
# 1    random_n60_k2_pos30_neg5_err5_2.g  59.00  11.13  55.02   0.71
# 2    random_n60_k2_pos30_neg5_err5_3.g  58.17  12.52  54.04   0.84
# 3    random_n60_k2_pos30_neg5_err5_4.g  59.33   0.65  53.99   0.93
# 4    random_n60_k2_pos30_neg5_err5_5.g  58.50   0.74  54.30   0.88
# 5   random_n60_k2_pos30_neg5_err10_1.g  58.00   0.61  53.80   0.73
# 6   random_n60_k2_pos30_neg5_err10_2.g  59.00   0.73  54.45   0.91
# 7   random_n60_k2_pos30_neg5_err10_3.g  57.33  12.94  52.74   0.74
# 8   random_n60_k2_pos30_neg5_err10_4.g  59.00   0.68  53.60   0.93
# 9   random_n60_k2_pos30_neg5_err10_5.g  58.25   0.73  53.89   0.85
# 10  random_n60_k2_pos30_neg5_err20_1.g  57.67   1.57  53.56   0.75
# 11  random_n60_k2_pos30_neg5_err20_2.g  58.00   1.89  53.74   0.66
# 12  random_n60_k2_pos30_neg5_err20_3.g  56.33   0.70  52.14   0.71
# ...

# %%
method_ = "mip"
file=f"../result/{method_}_n{n_}_{prob_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_mip0 = pd.DataFrame()
table_mip0 = pd.concat([table_mip0, df], ignore_index=True)
table_mip0.columns = ['instance','bb0','bs0','gap0','time0','nodes0','opt0']


method_ = "mip"
file=f"../result/{method_}_n{n_}_{prob_}_ineq9.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table_mip1 = pd.DataFrame()
table_mip1 = pd.concat([table_mip1, df], ignore_index=True)
table_mip1.columns = ['instance','bb1','bs1','gap1','time1','nodes1','opt1']

table_mip0['gap1'] = table_mip1['gap1']
table_mip0['time1'] = table_mip1['time1']
table_mip0['nodes1'] = table_mip1['nodes1']
table_mip0['opt1'] = table_mip1['opt1']

table_mip0
# Out:
#                               instance   bb0   bs0  gap0   time0  nodes0  \
# 0    random_n60_k2_pos30_neg5_err5_1.g  47.0  47.0   0.0  156.99    14.0
# 1    random_n60_k2_pos30_neg5_err5_2.g  54.0  54.0   0.0    9.91     1.0
# 2    random_n60_k2_pos30_neg5_err5_3.g  53.0  53.0   0.0   12.13     1.0
# 3    random_n60_k2_pos30_neg5_err5_4.g  49.0  49.0   0.0   31.40     1.0
# 4    random_n60_k2_pos30_neg5_err5_5.g  49.0  49.0   0.0   84.25     1.0
# 5   random_n60_k2_pos30_neg5_err10_1.g  42.0  42.0   0.0  116.11   181.0
# 6   random_n60_k2_pos30_neg5_err10_2.g  48.0  48.0   0.0   66.03    17.0
# 7   random_n60_k2_pos30_neg5_err10_3.g  43.0  43.0   0.0  127.07   170.0
# 8   random_n60_k2_pos30_neg5_err10_4.g  39.0  39.0   0.0  161.93   542.0
# 9   random_n60_k2_pos30_neg5_err10_5.g  42.0  42.0   0.0  163.58   294.0
# 10  random_n60_k2_pos30_neg5_err20_1.g  36.0  36.0   0.0  148.24  2554.0
# 11  random_n60_k2_pos30_neg5_err20_2.g  37.0  37.0   0.0  565.32  1854.0
# ...
